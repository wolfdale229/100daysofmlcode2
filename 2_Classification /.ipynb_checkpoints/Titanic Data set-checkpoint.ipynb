# %% [markdown]
# #  Titanic data set classification exercise

# %% [markdown]
# The purpose of the exercise is to look into the Titanic dataset, analyse the data to help determine which passenger survived when the accident. The data set is gotten from the kaggle's competition website.

# %% [markdown]
# ## imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt


sb.set_style('darkgrid')

# %% [markdown]
# ## Load data set

# %%
filepath ='../data/titanic/'
filename = 'train.csv'
# !ls {filepath}
# Out:
# test.csv  train.csv

# %%
df = pd.read_csv(f'{filepath + filename}', sep=',')
df.columns = df.columns.str.lower() # changes the column names to lower case, this doesn't improve the dataset

# %%
df.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df.head().T
# Out:
#                                    0  \
# passengerid                        1
# survived                           0
# pclass                             3
# name         Braund, Mr. Owen Harris
# sex                             male
# age                               22
# sibsp                              1
# parch                              0
# ticket                     A/5 21171
# fare                            7.25
# cabin                            NaN
# embarked                           S
#
#                                                              1  \
# passengerid                                                  2
# survived                                                     1
# pclass                                                       1
# name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                     female
# age                                                         38
# sibsp                                                        1
# parch                                                        0
# ticket                                                PC 17599
# fare                                                   71.2833
# cabin                                                      C85
# embarked                                                     C
#
#                                   2  \
# passengerid                       3
# survived                          1
# pclass                            3
# name         Heikkinen, Miss. Laina
# sex                          female
# age                              26
# sibsp                             0
# parch                             0
# ticket             STON/O2. 3101282
# fare                          7.925
# cabin                           NaN
# embarked                          S
#
#                                                         3  \
# passengerid                                             4
# survived                                                1
# pclass                                                  1
# name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# sex                                                female
# age                                                    35
# sibsp                                                   1
# parch                                                   0
# ticket                                             113803
# fare                                                 53.1
# cabin                                                C123
# embarked                                                S
#
#                                     4
# passengerid                         5
# survived                            0
# pclass                              3
# name         Allen, Mr. William Henry
# sex                              male
# age                                35
# sibsp                               0
# parch                               0
# ticket                         373450
# fare                             8.05
# cabin                             NaN
# embarked                            S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        passengerid    survived      pclass         age       sibsp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             parch        fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.hist(figsize=(10, 8))
plt.show()

# %%
df.isnull().sum()
# Out:
# passengerid      0
# survived         0
# pclass           0
# name             0
# sex              0
# age            177
# sibsp            0
# parch            0
# ticket           0
# fare             0
# cabin          687
# embarked         2
# dtype: int64

# %% [markdown]
# ##  Data preprocessing

# %%
df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      parch            ticket     fare cabin embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Before dealing with missing data, let's first expand the data set. I would focus on only
# - The `age` column
# - The `name` column
# - The `fare` column

# %% [markdown]
# I am creating a new column that looks at the **age** distribution and group each individual into either **Teen**, **youth**, **Adult** or **Old**.

# %%
'''This function does a conditional check of the age range and returns a age category, 
if the age value is missing it returns a np.nan value'''

def age_dist(x):
    if x < 21:
        return 'young'
    elif x >=21 and x <= 40:
        return 'youth'
    elif x >=41 and x <= 60:
        return 'adult'
    elif x > 60 :
        return 'old'
    else :
        return np.nan
    
df['age_class'] = df['age'].apply(lambda x : age_dist(x))

# %%
df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      parch            ticket     fare cabin embarked age_class
# 0        0         A/5 21171   7.2500   NaN        S     youth
# 1        0          PC 17599  71.2833   C85        C     youth
# 2        0  STON/O2. 3101282   7.9250   NaN        S     youth
# 3        0            113803  53.1000  C123        S     youth
# 4        0            373450   8.0500   NaN        S     youth
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S     youth
# 887      0            112053  30.0000   B42        S     young
# 888      2        W./C. 6607  23.4500   NaN        S       NaN
# 889      0            111369  30.0000  C148        C     youth
# 890      0            370376   7.7500   NaN        Q     youth
#
# [891 rows x 13 columns]

# %%
df['age_class'].unique() # check if the function worked
# Out:
# array(['youth', nan, 'adult', 'young', 'old'], dtype=object)

# %% [markdown]
# Doing the same thing with the **fare** column. from the column's histogram plot three distinct classes can be seen. A new column which indicates the passengers societal class would be created using the the histogram distribution. The classes are **poor**, **middle class** and **rich**

# %%
df.fare.hist(figsize=(10, 6))
plt.show()

# %%
df['social_class'] = pd.cut(df['fare'], bins=[0, 50, 100, np.inf], labels=['poor',  'middel_class', 'rich'])

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked age_class  social_class
# 0      0         A/5 21171   7.2500   NaN        S     youth          poor
# 1      0          PC 17599  71.2833   C85        C     youth  middel_class
# 2      0  STON/O2. 3101282   7.9250   NaN        S     youth          poor
# 3      0            113803  53.1000  C123        S     youth  middel_class
# 4      0            373450   8.0500   NaN        S     youth          poor

# %%
df['social_class'].unique()
# Out:
# [poor, middel_class, rich, NaN]
# Categories (3, object): [poor < middel_class < rich]

# %% [markdown]
# For the **name** column, two extra columns would be extracted from it.
# <!-- - **Marital status** of the passenger -->
# - Boolean column that indicates if the passenger has a **Siblin**

# %%
df['name'].isnull().sum() # Since it has no missing value no need to bother about np.nan conditions
# Out:
# 0

# %%
df['sib_present'] = df.sibsp.apply(lambda x : x >= 1 , True)

# %%
df['sib_present'].unique()
# Out:
# array([ True, False])

# %%
df.isnull().sum()
# Out:
# passengerid       0
# survived          0
# pclass            0
# name              0
# sex               0
# age             177
# sibsp             0
# parch             0
# ticket            0
# fare              0
# cabin           687
# embarked          2
# age_class       179
# social_class     15
# sib_present       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passengerid   891 non-null    int64
#  1   survived      891 non-null    int64
#  2   pclass        891 non-null    int64
#  3   name          891 non-null    object
#  4   sex           891 non-null    object
#  5   age           714 non-null    float64
#  6   sibsp         891 non-null    int64
#  7   parch         891 non-null    int64
#  8   ticket        891 non-null    object
#  9   fare          891 non-null    float64
#  10  cabin         204 non-null    object
#  11  embarked      889 non-null    object
#  12  age_class     712 non-null    object
#  13  social_class  876 non-null    category
#  14  sib_present   891 non-null    bool
# dtypes: bool(1), category(1), float64(2), int64(5), object(6)
# memory usage: 92.5+ KB

# %% [markdown]
# ### Dealing with missing data, categorical and string columns

# %%
# Searching for empyt entries, creating a column that indicates it's entry value
for column, value in df.items():
    if pd.isnull(value).sum():
        df[column+'_na'] = pd.isnull(value)

# %%
df.T
# Out:
#                                      0    \
# passengerid                            1
# survived                               0
# pclass                                 3
# name             Braund, Mr. Owen Harris
# sex                                 male
# age                                   22
# sibsp                                  1
# parch                                  0
# ticket                         A/5 21171
# fare                                7.25
# cabin                                NaN
# embarked                               S
# age_class                          youth
# social_class                        poor
# sib_present                         True
# age_na                             False
# cabin_na                            True
# embarked_na                        False
# age_class_na                       False
# social_class_na                    False
#
#                                                                1    \
# passengerid                                                      2
# survived                                                         1
# pclass                                                           1
# name             Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                         female
# age                                                             38
# sibsp                                                            1
# parch                                                            0
# ticket                                                    PC 17599
# fare                                                       71.2833
# cabin                                                          C85
# embarked                                                         C
# age_class                                                    youth
# social_class                                          middel_class
# sib_present                                                   True
# age_na                                                       False
# cabin_na                                                     False
# embarked_na                                                  False
# age_class_na                                                 False
# social_class_na                                              False
#
#                                     2    \
# passengerid                           3
# survived                              1
# pclass                                3
# name             Heikkinen, Miss. Laina
# sex                              female
# age                                  26
# sibsp                                 0
# parch                                 0
# ticket                 STON/O2. 3101282
# fare                              7.925
# cabin                               NaN
# embarked                              S
# age_class                         youth
# social_class                       poor
# sib_present                       False
# age_na                            False
# cabin_na                           True
# embarked_na                       False
# age_class_na                      False
# social_class_na                   False
#
#                                                           3    \
# passengerid                                                 4
# survived                                                    1
# pclass                                                      1
# name             Futrelle, Mrs. Jacques Heath (Lily May Peel)
# sex                                                    female
# age                                                        35
# sibsp                                                       1
# parch                                                       0
# ticket                                                 113803
# fare                                                     53.1
# cabin                                                    C123
# embarked                                                    S
# age_class                                               youth
# social_class                                     middel_class
# sib_present                                              True
# age_na                                                  False
# cabin_na                                                False
# embarked_na                                             False
# age_class_na                                            False
# social_class_na                                         False
#
#                                       4                 5    \
# passengerid                             5                 6
# survived                                0                 0
# pclass                                  3                 3
# name             Allen, Mr. William Henry  Moran, Mr. James
# sex                                  male              male
# age                                    35               NaN
# sibsp                                   0                 0
# parch                                   0                 0
# ticket                             373450            330877
# fare                                 8.05            8.4583
# cabin                                 NaN               NaN
# embarked                                S                 Q
# age_class                           youth               NaN
# social_class                         poor              poor
# sib_present                         False             False
# age_na                              False              True
# cabin_na                             True              True
# embarked_na                         False             False
# age_class_na                        False              True
# social_class_na                     False             False
#
#                                      6                               7    \
# passengerid                            7                               8
# survived                               0                               0
# pclass                                 1                               3
# name             McCarthy, Mr. Timothy J  Palsson, Master. Gosta Leonard
# sex                                 male                            male
# age                                   54                               2
# sibsp                                  0                               3
# parch                                  0                               1
# ticket                             17463                          349909
# fare                             51.8625                          21.075
# cabin                                E46                             NaN
# embarked                               S                               S
# age_class                          adult                           young
# social_class                middel_class                            poor
# sib_present                        False                            True
# age_na                             False                           False
# cabin_na                           False                            True
# embarked_na                        False                           False
# age_class_na                       False                           False
# social_class_na                    False                           False
#
#                                                                8    \
# passengerid                                                      9
# survived                                                         1
# pclass                                                           3
# name             Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# sex                                                         female
# age                                                             27
# sibsp                                                            0
# parch                                                            2
# ticket                                                      347742
# fare                                                       11.1333
# cabin                                                          NaN
# embarked                                                         S
# age_class                                                    youth
# social_class                                                  poor
# sib_present                                                  False
# age_na                                                       False
# cabin_na                                                      True
# embarked_na                                                  False
# age_class_na                                                 False
# social_class_na                                              False
#
#                                                  9    ...                 881  \
# passengerid                                       10  ...                 882
# survived                                           1  ...                   0
# pclass                                             2  ...                   3
# name             Nasser, Mrs. Nicholas (Adele Achem)  ...  Markun, Mr. Johann
# sex                                           female  ...                male
# age                                               14  ...                  33
# sibsp                                              1  ...                   0
# parch                                              0  ...                   0
# ticket                                        237736  ...              349257
# fare                                         30.0708  ...              7.8958
# cabin                                            NaN  ...                 NaN
# embarked                                           C  ...                   S
# age_class                                      young  ...               youth
# social_class                                    poor  ...                poor
# sib_present                                     True  ...               False
# age_na                                         False  ...               False
# cabin_na                                        True  ...                True
# embarked_na                                    False  ...               False
# age_class_na                                   False  ...               False
# social_class_na                                False  ...               False
#
#                                           882                            883  \
# passengerid                               883                            884
# survived                                    0                              0
# pclass                                      3                              2
# name             Dahlberg, Miss. Gerda Ulrika  Banfield, Mr. Frederick James
# sex                                    female                           male
# age                                        22                             28
# sibsp                                       0                              0
# parch                                       0                              0
# ticket                                   7552               C.A./SOTON 34068
# fare                                  10.5167                           10.5
# cabin                                     NaN                            NaN
# embarked                                    S                              S
# age_class                               youth                          youth
# social_class                             poor                           poor
# sib_present                             False                          False
# age_na                                  False                          False
# cabin_na                                 True                           True
# embarked_na                             False                          False
# age_class_na                            False                          False
# social_class_na                         False                          False
#
#                                     884                                   885  \
# passengerid                         885                                   886
# survived                              0                                     0
# pclass                                3                                     3
# name             Sutehall, Mr. Henry Jr  Rice, Mrs. William (Margaret Norton)
# sex                                male                                female
# age                                  25                                    39
# sibsp                                 0                                     0
# parch                                 0                                     5
# ticket                  SOTON/OQ 392076                                382652
# fare                               7.05                                29.125
# cabin                               NaN                                   NaN
# embarked                              S                                     Q
# age_class                         youth                                 youth
# social_class                       poor                                  poor
# sib_present                       False                                 False
# age_na                            False                                 False
# cabin_na                           True                                  True
# embarked_na                       False                                 False
# age_class_na                      False                                 False
# social_class_na                   False                                 False
#
#                                    886                           887  \
# passengerid                        887                           888
# survived                             0                             1
# pclass                               2                             1
# name             Montvila, Rev. Juozas  Graham, Miss. Margaret Edith
# sex                               male                        female
# age                                 27                            19
# sibsp                                0                             0
# parch                                0                             0
# ticket                          211536                        112053
# fare                                13                            30
# cabin                              NaN                           B42
# embarked                             S                             S
# age_class                        youth                         young
# social_class                      poor                          poor
# sib_present                      False                         False
# age_na                           False                         False
# cabin_na                          True                         False
# embarked_na                      False                         False
# age_class_na                     False                         False
# social_class_na                  False                         False
#
#                                                       888  \
# passengerid                                           889
# survived                                                0
# pclass                                                  3
# name             Johnston, Miss. Catherine Helen "Carrie"
# sex                                                female
# age                                                   NaN
# sibsp                                                   1
# parch                                                   2
# ticket                                         W./C. 6607
# fare                                                23.45
# cabin                                                 NaN
# embarked                                                S
# age_class                                             NaN
# social_class                                         poor
# sib_present                                          True
# age_na                                               True
# cabin_na                                             True
# embarked_na                                         False
# age_class_na                                         True
# social_class_na                                     False
#
#                                    889                  890
# passengerid                        890                  891
# survived                             1                    0
# pclass                               1                    3
# name             Behr, Mr. Karl Howell  Dooley, Mr. Patrick
# sex                               male                 male
# age                                 26                   32
# sibsp                                0                    0
# parch                                0                    0
# ticket                          111369               370376
# fare                                30                 7.75
# cabin                             C148                  NaN
# embarked                             C                    Q
# age_class                        youth                youth
# social_class                      poor                 poor
# sib_present                      False                False
# age_na                           False                False
# cabin_na                         False                 True
# embarked_na                      False                False
# age_class_na                     False                False
# social_class_na                  False                False
#
# [20 rows x 891 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   passengerid      891 non-null    int64
#  1   survived         891 non-null    int64
#  2   pclass           891 non-null    int64
#  3   name             891 non-null    category
#  4   sex              891 non-null    category
#  5   age              714 non-null    float64
#  6   sibsp            891 non-null    int64
#  7   parch            891 non-null    int64
#  8   ticket           891 non-null    category
#  9   fare             891 non-null    float64
#  10  cabin            204 non-null    category
#  11  embarked         889 non-null    category
#  12  age_class        712 non-null    category
#  13  social_class     876 non-null    category
#  14  sib_present      891 non-null    bool
#  15  age_na           891 non-null    bool
#  16  cabin_na         891 non-null    bool
#  17  embarked_na      891 non-null    bool
#  18  age_class_na     891 non-null    bool
#  19  social_class_na  891 non-null    bool
# dtypes: bool(6), category(7), float64(2), int64(5)
# memory usage: 141.7 KB

# %%
# converting strings to categorical data
attr = ['sex', 'ticket', 'cabin', 'embarked', 'age_class', 'name']
for label, value in df[attr].items():
       df[label] = df[label].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   passengerid      891 non-null    int64
#  1   survived         891 non-null    int64
#  2   pclass           891 non-null    int64
#  3   name             891 non-null    category
#  4   sex              891 non-null    category
#  5   age              714 non-null    float64
#  6   sibsp            891 non-null    int64
#  7   parch            891 non-null    int64
#  8   ticket           891 non-null    category
#  9   fare             891 non-null    float64
#  10  cabin            204 non-null    category
#  11  embarked         889 non-null    category
#  12  age_class        712 non-null    category
#  13  social_class     876 non-null    category
#  14  sib_present      891 non-null    bool
#  15  age_na           891 non-null    bool
#  16  cabin_na         891 non-null    bool
#  17  embarked_na      891 non-null    bool
#  18  age_class_na     891 non-null    bool
#  19  social_class_na  891 non-null    bool
# dtypes: bool(6), category(7), float64(2), int64(5)
# memory usage: 141.7 KB

# %%
df.isnull().sum()
# Out:
# passengerid          0
# survived             0
# pclass               0
# name                 0
# sex                  0
# age                177
# sibsp                0
# parch                0
# ticket               0
# fare                 0
# cabin              687
# embarked             2
# age_class          179
# social_class        15
# sib_present          0
# age_na               0
# cabin_na             0
# embarked_na          0
# age_class_na         0
# social_class_na      0
# dtype: int64

# %%
X, y = df.drop('survived', axis=1).copy(), df['survived'].copy()
X
# Out:
#      passengerid  pclass                                               name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#     age_class  social_class  sib_present  age_na  cabin_na  embarked_na  \
# 0       youth          poor         True   False      True        False
# 1       youth  middel_class         True   False     False        False
# 2       youth          poor        False   False      True        False
# 3       youth  middel_class         True   False     False        False
# 4       youth          poor        False   False      True        False
# ..        ...           ...          ...     ...       ...          ...
# 886     youth          poor        False   False      True        False
# 887     young          poor        False   False     False        False
# 888       NaN          poor         True    True      True        False
# 889     youth          poor        False   False     False        False
# 890     youth          poor        False   False      True        False
#
#      age_class_na  social_class_na
# 0           False            False
# 1           False            False
# 2           False            False
# 3           False            False
# 4           False            False
# ..            ...              ...
# 886         False            False
# 887         False            False
# 888          True            False
# 889         False            False
# 890         False            False
#
# [891 rows x 19 columns]

# %% [markdown]
# ## Visualization

# %%
df = df.copy()

# %%
pd.crosstab(df['age'], df['age_class']).plot(figsize=(10, 8))
plt.show()
