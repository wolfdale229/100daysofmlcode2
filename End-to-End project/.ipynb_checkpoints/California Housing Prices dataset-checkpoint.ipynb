# %% [markdown]
# # California housing data set

# %% [markdown]
# ## imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from pandas.plotting import scatter_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedShuffleSplit, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

sns.set_style('darkgrid')

# %% [markdown]
# ## Loading the data

# %%
file = '../data/california/housing.csv'
# !ls {file}
# Out:
# ../data/california/housing.csv

# %%
def load_data(file):
    csv_file = pd.read_csv(file, sep=',')
    return csv_file
housing =load_data(file)

# %% [markdown]
# ## Understanding the data

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
housing['median_income'].hist(bins=50, figsize=(9, 4))
plt.show()

# %% [markdown]
# ## Creating train and test sets

# %%
# def set_splits(df, size, random_state=0):
#     np.random.seed(random_state)
#     shuffle = np.random.permutation(df)
#     split_size = int(len(df) * size)
#     return df[split_size:], df[:split_size]
# train, test = set_splits(housing, 0.2)

# %%
# creating a median_income strata for stratifying the dataset
housing['income_cat'] = pd.cut(housing['median_income'], 
                               bins=[0., 1.5, 3.0, 4.5, 6.0, np.inf], 
                              labels=[1, 2, 3, 4, 5])
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing['income_cat'].hist();

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_size, test_size in split.split(housing, housing['income_cat']):
    strat_train_set = housing.loc[train_size]
    strat_test_set = housing.loc[test_size]

# %%
strat_test_set['income_cat'].value_counts() / len(strat_test_set)
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114583
# 1    0.039729
# Name: income_cat, dtype: float64

# %%
# removing the sampling column
for income_cat in (strat_test_set, strat_train_set):
    income_cat.drop('income_cat', axis=1, inplace=True)

# %%
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17606    -121.89     37.29                38.0       1568.0           351.0
# 18632    -121.93     37.05                14.0        679.0           108.0
# 14650    -117.20     32.77                31.0       1952.0           471.0
# 3230     -119.61     36.31                25.0       1847.0           371.0
# 3555     -118.59     34.23                17.0       6592.0          1525.0
# ...          ...       ...                 ...          ...             ...
# 6563     -118.13     34.20                46.0       1271.0           236.0
# 12053    -117.56     33.88                40.0       1196.0           294.0
# 13908    -116.40     34.09                 9.0       4855.0           872.0
# 11159    -118.01     33.82                31.0       1960.0           380.0
# 15775    -122.45     37.77                52.0       3095.0           682.0
#
# ...

# %% [markdown]
# ## Visualizing the dataset to gain insights
# **from now on we should only work with a copy of the training set**

# %%
housing = strat_train_set.copy()

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
             s=housing["population"]/100, label="population", figsize=(10,7),
             c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
             )
plt.legend()
plt.show()

# %%
cor_matrix = housing.corr()
cor_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687160
# total_rooms           0.135097
# housing_median_age    0.114110
# households            0.064506
# total_bedrooms        0.047689
# population           -0.026920
# longitude            -0.047432
# latitude             -0.142724
# Name: median_house_value, dtype: float64

# %%
# location settlement of high median_income earners
sns.relplot(x='longitude', y='latitude', 
            data=housing[housing['median_income'] > 7.5], palette='jet');

# %%
attributes = ["median_house_value", "median_income", "total_rooms",
              "housing_median_age"]
scatter_matrix(housing[attributes],  figsize=(15, 8))
plt.show()

# %%
sns.relplot(x='median_income', y='median_house_value', 
            data=housing, palette='jet');
plt.show()

# %%
housing["rooms_per_household"] = housing["total_rooms"]/housing["households"]
housing["bedrooms_per_room"] = housing["total_bedrooms"]/housing["total_rooms"]
housing["population_per_household"]=housing["population"]/housing["households"]

# %%
cor_matrix = housing.corr()
cor_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.687160
# rooms_per_household         0.146285
# total_rooms                 0.135097
# housing_median_age          0.114110
# households                  0.064506
# total_bedrooms              0.047689
# population_per_household   -0.021985
# population                 -0.026920
# longitude                  -0.047432
# latitude                   -0.142724
# bedrooms_per_room          -0.259984
# Name: median_house_value, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=cor_matrix, annot=True, fmt='.2f');
plt.show()

# %% [markdown]
# ## Prepare the Data for Machine Learning Algorithms

# %%
# creating the dependent variables and independent variables from the train set
def split_df(df, columnName):
    ''' Seperate the dataframe into the dependent (X) and target (y) variables'''
    features = df.drop(columnName, axis=1).copy()
    label = df[columnName].copy()
    return features, label

# %%
housing, housing_label = split_df(strat_train_set, 'median_house_value')
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17606    -121.89     37.29                38.0       1568.0           351.0
# 18632    -121.93     37.05                14.0        679.0           108.0
# 14650    -117.20     32.77                31.0       1952.0           471.0
# 3230     -119.61     36.31                25.0       1847.0           371.0
# 3555     -118.59     34.23                17.0       6592.0          1525.0
# ...          ...       ...                 ...          ...             ...
# 6563     -118.13     34.20                46.0       1271.0           236.0
# 12053    -117.56     33.88                40.0       1196.0           294.0
# 13908    -116.40     34.09                 9.0       4855.0           872.0
# 11159    -118.01     33.82                31.0       1960.0           380.0
# 15775    -122.45     37.77                52.0       3095.0           682.0
#
# ...

# %%
# My code
def process_data(df):
    # handling missing values
    for column, value in df.items():
        if pd.api.types.is_numeric_dtype(value):
            if pd.isnull(value).sum():
                df[column+'_na'] = pd.isnull(value)
#                 df[column] = value.fillna(value.median())
#     for column, value in df.items():
#         if not pd.api.types.is_numeric_dtype(value):
#             df[column] = value.astype('category')
#     for column, value in df.items():
#         if not pd.api.types.is_numeric_dtype(value):
#             df[column] = value.cat.as_ordered()
#             df[column] = value.cat.codes+1
    
    return df
housing = process_data(housing)

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17606    -121.89     37.29                38.0       1568.0           351.0
# 18632    -121.93     37.05                14.0        679.0           108.0
# 14650    -117.20     32.77                31.0       1952.0           471.0
# 3230     -119.61     36.31                25.0       1847.0           371.0
# 3555     -118.59     34.23                17.0       6592.0          1525.0
# ...          ...       ...                 ...          ...             ...
# 6563     -118.13     34.20                46.0       1271.0           236.0
# 12053    -117.56     33.88                40.0       1196.0           294.0
# 13908    -116.40     34.09                 9.0       4855.0           872.0
# 11159    -118.01     33.82                31.0       1960.0           380.0
# 15775    -122.45     37.77                52.0       3095.0           682.0
#
# ...

# %%
num_attr = list(housing.drop('ocean_proximity', axis=1))
cat_attr = ['ocean_proximity']

num_pipeline = Pipeline([
    ('fill_missing', SimpleImputer(strategy='median')),
    ('scaling', StandardScaler())
     ],
    )

full_transform = ColumnTransformer([
    ('num', num_pipeline, num_attr),
    ('cat', OneHotEncoder(), cat_attr)],
    remainder='passthrough'
)

housing_prepared = full_transform.fit_transform(housing)

# %%
X, y = housing_prepared, housing_label

# %% [markdown]
# ## Building a model

# %% [markdown]
# ### Selecting Model

# %% [markdown]
# #### LinearRegression

# %%
lin_reg = LinearRegression().fit(X, y)

# %%
some_data = housing.iloc[:5]
some_label = housing_label[:5]

some_data_prepared = full_transform.transform(some_data)

pred = lin_reg.predict(some_data_prepared)
# print('{}'.format(pred))

lin_reg_rmse = np.sqrt(mean_squared_error(pred, some_label))
print(lin_reg_rmse)
# Out:
# 45406.62634756947

# %%
y_pred = lin_reg.predict(X)
lin_mse = np.sqrt(mean_squared_error(y, y_pred))
lin_mse
# Out:
# 69050.51999733978

# %% [markdown]
# #### Decision Tree Regrssion

# %%
tree_reg = DecisionTreeRegressor().fit(X, y)
y_pred = tree_reg.predict(X)

tree_rmse = np.sqrt(mean_squared_error(y, y_pred))
print(tree_rmse)
# Out:
# 0.0

# %% [markdown]
# #### Random Forest Regression

# %%
rf_reg = RandomForestRegressor().fit(X, y)
y_pred = rf_reg.predict(X)
rf_rmse = np.sqrt(mean_squared_error(y, y_pred))
print(rf_rmse)
# Out:
# 18316.402418775488

# %% [markdown]
# #### Support Vector machines

# %%
svc_reg = SVR().fit(X, y)
y_pred = svc_reg.predict(X)
svc_rmse = np.sqrt(mean_squared_error(y, y_pred))
print(svc_rmse)
# Out:
# 118569.38553932308

# %% [markdown]
# ####  Neural network

# %%
mlp = MLPRegressor().fit(X, y)
y_pred = mlp.predict(X)
mlp_rmse = np.sqrt(mean_squared_error(y, y_pred))
print(mlp_rmse)
# Out:
# 168852.5541209812
# /home/eclipse/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# ### Cross Validation score

# %%
def display_scores(scores):
    print(f'Scores : {scores}\n')
    print(f"Mean : {scores.mean()}")
    print(f'Standard Deviation : {scores.std()}')

# %%
scores = cross_val_score(tree_reg, X, y, scoring='neg_mean_squared_error', cv=10, n_jobs=-1)
tree_rmse = np.sqrt(-scores)
display_scores(tree_rmse)
# Out:
# Scores : [67836.74393898 67209.87493774 73366.29670598 70541.46861491
#  69697.65798484 76104.08498143 67638.87850698 70540.43488242
#  71306.02886456 69243.53699565]
#
# Mean : 70348.50064134921
# Standard Deviation : 2614.789969494262

# %%
scores = cross_val_score(lin_reg, X, y, scoring='neg_mean_squared_error', cv=10, n_jobs=-1)
lin_rmse = np.sqrt(-scores)
display_scores(lin_rmse)
# Out:
# Scores : [67448.63030088 67287.65528327 68593.01784964 74581.83814184
#  68311.93557103 71463.73960912 65360.11100271 68782.11481491
#  72484.97731242 68150.95150922]
#
# Mean : 69246.49713950274
# Standard Deviation : 2622.202835044064

# %%
scores = cross_val_score(rf_reg, X, y, scoring='neg_mean_squared_error', cv=10, n_jobs=-1)
rf_scores = np.sqrt(-scores)
display_scores(rf_scores)
# Out:
# Scores : [47636.97574324 46363.96862009 49182.08518813 49999.92877843
#  49180.63263983 52716.57637458 48828.02005719 50532.92527814
#  51459.88916271 49116.48603936]
#
# Mean : 49501.74878816931
# Standard Deviation : 1720.8027043124973

# %%
scores = cross_val_score(svc_reg, X, y, scoring='neg_mean_squared_error', cv=10, n_jobs=-1)
svc_scores = np.sqrt(-scores)
display_scores(svc_scores)
# Out:
# Scores : [111378.07876526 119536.45397939 116957.88043553 120448.30477382
#  117609.86842379 122316.71899009 117629.56841735 121467.97796626
#  120343.11844554 118005.47963979]
#
# Mean : 118569.34498368143
# Standard Deviation : 2940.914726949721

# %%
scores = cross_val_score(mlp, X, y, scoring='neg_mean_squared_error', cv=10, n_jobs=-1)
mlp_scores = np.sqrt(-scores)
display_scores(mlp_scores)
# Out:
# Scores : [170352.50985029 178965.11780499 173079.23902133 181311.51195946
#  174789.15646933 190793.68700801 176569.38626907 180605.41648856
#  176078.97495862 180853.0012266 ]
#
# Mean : 178339.80010562605
# Standard Deviation : 5367.43574054045

# %% [markdown]
# ## Fine-Tune Your Model
